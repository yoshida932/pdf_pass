# %%
run_this = True
if run_this:
    import os
    os.chdir(r'C:\Users\yyoshida\Documents\back-up folder Lets Note\1_授業資料\2 人間発達\2026 人間発達学\2026_助産診断・ケア論\2026 名簿と試験')
    print("現在の作業ディレクトリ:", os.getcwd())
    print("このセルは実行されました")
else:
    print("このセルはスキップされました")


from PyPDF2 import PdfReader, PdfWriter


input_pdf = "名簿.pdf"
output_pdf = "名簿_p.pdf"


reader = PdfReader(input_pdf)
writer = PdfWriter()


# 全ページをコピー
for page in reader.pages:
    writer.add_page(page)


# パスワード設定
# user_pwd : PDFを開くためのパスワード
# owner_pwd: 印刷や編集制限を解除できる管理者パスワード
writer.encrypt(
    user_pwd="Rehabili@1804",
    #owner_pwd="ownerpassword",  # 省略可
    use_128bit=True
)


with open(output_pdf, "wb") as f:
    writer.write(f)
# Out:
# 現在の作業ディレクトリ: C:\Users\yyoshida\Documents\back-up folder Lets Note\1_授業資料\2 人間発達\2026 人間発達学\2026_助産診断・ケア論\2026 名簿と試験
# このセルは実行されました
# c:\Users\yyoshida\miniconda3\envs\py310\lib\site-packages\PyPDF2\_writer.py:886: UserWarning: Please use 'user_password' instead of 'user_pwd'. The 'user_pwd' argument is deprecated and will be removed in PyPDF2 4.0.0.
#   warnings.warn(

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\yyoshida\miniconda3\envs\py310\python.exe
